# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout
)
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# Fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# Load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One-hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the modified model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# Compile model using legacy SGD optimizer
epochs = 25
learning_rate = 0.01
sgd = SGD(learning_rate=learning_rate, momentum=0.9, nesterov=False)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32, verbose=1)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 10s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 25s 8ms/step - loss: 1.8346 - accuracy: 0.3208 - val_loss: 1.5248 - val_accuracy: 0.4222
# Epoch 2/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.3816 - accuracy: 0.4985 - val_loss: 1.1543 - val_accuracy: 0.5905
# Epoch 3/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1597 - accuracy: 0.5846 - val_loss: 1.0262 - val_accuracy: 0.6427
# Epoch 4/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.0129 - accuracy: 0.6409 - val_loss: 0.9835 - val_accuracy: 0.6548
# Epoch 5/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9168 - accuracy: 0.6782 - val_loss: 0.8930 - val_accuracy: 0.6873
# Epoch 6/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.8293 - accuracy: 0.7099 - val_loss: 0.8095 - val_accuracy: 0.7220
# Epoch 7/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.7727 - accuracy: 0.7299 - val_loss: 0.8511 - val_accuracy: 0.7058
# Epoch 8/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7236 - accuracy: 0.7449 - val_loss: 0.7235 - val_accuracy: 0.7479
# Epoch 9/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6816 - accuracy: 0.7619 - val_loss: 0.7362 - val_accuracy: 0.7445
# Epoch 10/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6492 - accuracy: 0.7691 - val_loss: 0.7509 - val_accuracy: 0.7431
# Epoch 11/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6257 - accuracy: 0.7813 - val_loss: 0.7372 - val_accuracy: 0.7482
# Epoch 12/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5989 - accuracy: 0.7894 - val_loss: 0.6912 - val_accuracy: 0.7650
# Epoch 13/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5878 - accuracy: 0.7942 - val_loss: 0.7473 - val_accuracy: 0.7515
# Epoch 14/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5789 - accuracy: 0.7977 - val_loss: 0.7044 - val_accuracy: 0.7654
# Epoch 15/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5653 - accuracy: 0.8024 - val_loss: 0.7154 - val_accuracy: 0.7557
# Epoch 16/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5587 - accuracy: 0.8071 - val_loss: 0.7101 - val_accuracy: 0.7619
# Epoch 17/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5539 - accuracy: 0.8063 - val_loss: 0.7299 - val_accuracy: 0.7535
# Epoch 18/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5466 - accuracy: 0.8106 - val_loss: 0.7408 - val_accuracy: 0.7538
# Epoch 19/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5490 - accuracy: 0.8104 - val_loss: 0.7394 - val_accuracy: 0.7553
# Epoch 20/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5443 - accuracy: 0.8112 - val_loss: 0.7442 - val_accuracy: 0.7536
# Epoch 21/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5467 - accuracy: 0.8120 - val_loss: 0.7778 - val_accuracy: 0.7370
# Epoch 22/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5483 - accuracy: 0.8111 - val_loss: 0.7726 - val_accuracy: 0.7436
# Epoch 23/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5526 - accuracy: 0.8117 - val_loss: 0.7519 - val_accuracy: 0.7573
# Epoch 24/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5647 - accuracy: 0.8063 - val_loss: 0.7978 - val_accuracy: 0.7335
# Epoch 25/25
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.5686 - accuracy: 0.8070 - val_loss: 0.7835 - val_accuracy: 0.7462
# Accuracy: 74.62%

# %%
# Predict the first 4 images
predicted_classes = model.predict(X_test[:4])

# Convert predicted classes to labels
predicted_labels = np.argmax(predicted_classes, axis=1)

# Actual labels
actual_labels = np.argmax(y_test[:4], axis=1)

# Compare predictions with actual labels
for i in range(4):
    print(f"Predicted: {predicted_labels[i]}, Actual: {actual_labels[i]}")
# Out:
# 1/1 [==============================] - 0s 407ms/step
# Predicted: 8, Actual: 3
# Predicted: 8, Actual: 8
# Predicted: 8, Actual: 8
# Predicted: 8, Actual: 0

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
